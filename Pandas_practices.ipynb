# %%
import pandas as pd

df = pd.read_csv("dataset.csv", index_col ="id") #the index_col parameter convert the id in the consecutive for the rows

# %%
df.head() # this comand show the first 5 rows
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183721       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 183722      21.0       NaN   BRASIL  mateusmartins      982.0       1822
# 183723     123.0       6.0   MEXICO    pedrojuarez       12.0        129
# 183724      76.0       3.0  ECUADOR   galocastillo      332.0        378
# 183725     130.0       9.0   MEXICO    pedrojuarez       12.0        129

# %%
df.tail() # this comand show the last 5 rows
# Out:
#                                                 full_text  favorites  \
# id
# 183743                         Amazing video by Leonardo!      432.0
# 183744                                        Thanks man!      430.0
# 183745          There is nothing better than programming!      424.0
# 183746                                           BORED AF      488.0
# 183747  I do not know if i like programming or other t...      318.0
#
#         retweets  mentions country             user  followers  followees
# id
# 183743      95.0      18.0  BRASIL       lucasperes       82.0        351
# 183744     143.0      28.0  BRASIL       lucasperes        NaN        351
# 183745     110.0      29.0  BRASIL       lucasperes       82.0        351
# 183746      28.0      27.0  MEXICO  gabrielcarvajal       21.0       2721
# 183747      58.0      20.0  BRASIL  isabelladasilva      928.0       9918

# %%
df.describe() #show descriptive stats for the datafram, just the numeric columns
# Out:
#         favorites    retweets   mentions   followers    followees
# count   26.000000   26.000000  26.000000   26.000000    27.000000
# mean   280.538462   80.000000  15.423077  352.807692  1190.185185
# std    153.377242   40.303846   9.596554  375.319493  1965.735995
# min     23.000000   21.000000   1.000000   12.000000   129.000000
# 25%    139.250000   45.500000   8.250000   21.000000   258.000000
# 50%    305.500000   79.000000  16.000000  332.000000   351.000000
# 75%    422.500000  110.750000  23.500000  389.000000  1822.000000
# max    500.000000  146.000000  29.000000  982.000000  9918.000000

# %%
filter_df = df.dropna() #this function eliminate the NA values in the dataframe, but if you eliminate a lot of rows you cant do analysis

# %%
filter_df = df.fillna({"retweet": 0,"mentions":-1}) #This function change the NA values at the retweet and mentions columns by the specified values

filter_df.head()
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183721       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 183722      21.0      -1.0   BRASIL  mateusmartins      982.0       1822
# 183723     123.0       6.0   MEXICO    pedrojuarez       12.0        129
# 183724      76.0       3.0  ECUADOR   galocastillo      332.0        378
# 183725     130.0       9.0   MEXICO    pedrojuarez       12.0        129

# %%
filter_df = df.fillna(0) #this function replace the NA values by a selected valu, this is the general form 

filter_df
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        0.0
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# ...

# %% [markdown]
# In pandas you can filter dataframes by conditions or rows and columns

# %%
df["favorites"] #filter by column name
# Out:
# id
# 183721     23.0
# 183722    500.0
# 183723    190.0
# 183724    131.0
# 183725    113.0
# 183726    492.0
# 183727    158.0
# 183728      NaN
# 183729    198.0
# 183730    272.0
# 183731     43.0
# 183732    349.0
# 183733    467.0
# 183734     50.0
# 183735    418.0
# 183736    361.0
# 183737    346.0
# 183738    296.0
# 183739    315.0
# 183740    133.0
# 183741     92.0
# 183742    255.0
# 183743    432.0
# 183744    430.0
# 183745    424.0
# 183746    488.0
# 183747    318.0
# Name: favorites, dtype: float64

# %%
df.iloc[0:10] #fiter by index. filter the first 10 rows
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        NaN
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183721       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# ...

# %%
df.iloc[[0,1,2]] #filter by singular index
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183721       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 183722      21.0       NaN   BRASIL  mateusmartins      982.0       1822
# 183723     123.0       6.0   MEXICO    pedrojuarez       12.0        129

# %%
df.loc[[183729]] #loc function filter by id column
# Out:
#                                           full_text  favorites  retweets  \
# id
# 183729  OnePlus 8 international giveaway classifies      198.0      82.0
#
#         mentions country         user  followers  followees
# id
# 183729      26.0  MEXICO  pedrojuarez       12.0        129

# %%
df.loc[[183729],["favorites"]] #filter rows by id and columns by name
# Out:
#         favorites
# id
# 183729      198.0

# %%
df[(df["favorites"]>400) & (df["mentions"]>20)] #filter by favorites condition, the favorites be greater than 400 and & parameter
# Out:
#                                         full_text  favorites  retweets  \
# id
# 183744                                Thanks man!      430.0     143.0
# 183745  There is nothing better than programming!      424.0     110.0
# 183746                                   BORED AF      488.0      28.0
#
#         mentions country             user  followers  followees
# id
# 183744      28.0  BRASIL       lucasperes        NaN        351
# 183745      29.0  BRASIL       lucasperes       82.0        351
# 183746      27.0  MEXICO  gabrielcarvajal       21.0       2721

# %%
df[df["full_text"].str.contains("programming")] #this filter search the str tha contains the word programming,the filter differentiate lower and upper case
# Out:
#                                                 full_text  favorites  \
# id
# 183732  Its been in love with the game with the origin...      349.0
# 183745          There is nothing better than programming!      424.0
# 183747  I do not know if i like programming or other t...      318.0
#
#         retweets  mentions country             user  followers  followees
# id
# 183732      44.0      19.0  BRASIL    mateusmartins      982.0       1822
# 183745     110.0      29.0  BRASIL       lucasperes       82.0        351
# 183747      58.0      20.0  BRASIL  isabelladasilva      928.0       9918

# %%
import random
def calcularGanancias(retweets):  #this function calculates the value for the ganancia column
    ganancia = retweets *random.randint(3,5)
    return ganancia

df["ganancias"] = df["retweets"].apply(calcularGanancias)  #this line create ganancias column the function apply use the function at the selected column

def popularidad(fila):
    resultado = fila["followees"]/fila["followers"] #the parameter fila takes the rows at the selected columns one by one

# %%
    return resultado

df["popularidad"] = df.apply(popularidad, axis = 1)  #the parameter axis = 1 specify that the aplication must been row by row

df.head()
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
#
#         retweets  mentions  country           user  followers  followees  \
# id
# 183721       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 183722      21.0       NaN   BRASIL  mateusmartins      982.0       1822
# 183723     123.0       6.0   MEXICO    pedrojuarez       12.0        129
# 183724      76.0       3.0  ECUADOR   galocastillo      332.0        378
# 183725     130.0       9.0   MEXICO    pedrojuarez       12.0        129
#
#         ganancias  popularidad
# id
# 183721        NaN     0.663239
# 183722       63.0     1.855397
# ...

# %%
df.groupby("country").agg({
    "followers":"sum",
    "mentions":"mean",
    "retweets":"max"
}) 

#this function group the rows by the columns selected the parameter agg apply the function aggregate
# Out:
#          followers  mentions  retweets
# country
# BRASIL      6166.0    19.600     145.0
# ECUADOR     2884.0    11.875     146.0
# MEXICO       123.0    13.750     130.0
